# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From D:\ACA\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\ACA\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From D:\ACA\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 0.0066 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00215, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0016 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00215 to 0.00201, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0013 - val_loss: 0.0020
#
# Epoch 00003: val_loss improved from 0.00201 to 0.00196, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00196 to 0.00184, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0010 - val_loss: 0.0017
#
# Epoch 00005: val_loss improved from 0.00184 to 0.00174, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.1742e-04 - val_loss: 0.0016
#
# Epoch 00006: val_loss improved from 0.00174 to 0.00159, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 7.7968e-04 - val_loss: 0.0014
#
# Epoch 00007: val_loss improved from 0.00159 to 0.00138, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 6.5898e-04 - val_loss: 0.0012
#
# Epoch 00008: val_loss improved from 0.00138 to 0.00125, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 5.9355e-04 - val_loss: 0.0012
#
# Epoch 00009: val_loss improved from 0.00125 to 0.00121, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 5.2740e-04 - val_loss: 0.0011
#
# Epoch 00010: val_loss improved from 0.00121 to 0.00109, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 5.1238e-04 - val_loss: 0.0010
#
# Epoch 00011: val_loss improved from 0.00109 to 0.00102, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.5390e-04 - val_loss: 0.0010
#
# Epoch 00012: val_loss improved from 0.00102 to 0.00102, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.2472e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00102 to 0.00101, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.1027e-04 - val_loss: 9.6282e-04
#
# Epoch 00014: val_loss improved from 0.00101 to 0.00096, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.0158e-04 - val_loss: 9.5193e-04
#
# Epoch 00015: val_loss improved from 0.00096 to 0.00095, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.6005e-04 - val_loss: 9.2426e-04
#
# Epoch 00016: val_loss improved from 0.00095 to 0.00092, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.4941e-04 - val_loss: 8.9339e-04
#
# Epoch 00017: val_loss improved from 0.00092 to 0.00089, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.3811e-04 - val_loss: 8.5972e-04
#
# Epoch 00018: val_loss improved from 0.00089 to 0.00086, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.2729e-04 - val_loss: 8.2555e-04
#
# Epoch 00019: val_loss improved from 0.00086 to 0.00083, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.1484e-04 - val_loss: 8.4741e-04
#
# Epoch 00020: val_loss did not improve from 0.00083
# Epoch 21/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.0018e-04 - val_loss: 8.5552e-04
#
# Epoch 00021: val_loss did not improve from 0.00083
# Epoch 22/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.9262e-04 - val_loss: 8.5340e-04
#
# Epoch 00022: val_loss did not improve from 0.00083
# Epoch 23/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.8781e-04 - val_loss: 8.0548e-04
#
# Epoch 00023: val_loss improved from 0.00083 to 0.00081, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.7697e-04 - val_loss: 8.4972e-04
#
# Epoch 00024: val_loss did not improve from 0.00081
# Epoch 25/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 2.6298e-04 - val_loss: 8.6375e-04
#
# Epoch 00025: val_loss did not improve from 0.00081
# Epoch 26/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.5825e-04 - val_loss: 8.5693e-04
#
# Epoch 00026: val_loss did not improve from 0.00081
# Epoch 27/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 2.5635e-04 - val_loss: 7.8192e-04
#
# Epoch 00027: val_loss improved from 0.00081 to 0.00078, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 2.4860e-04 - val_loss: 8.1249e-04
#
# Epoch 00028: val_loss did not improve from 0.00078
# Epoch 29/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.4128e-04 - val_loss: 8.0743e-04
#
# Epoch 00029: val_loss did not improve from 0.00078
# Epoch 30/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.4021e-04 - val_loss: 7.8258e-04
#
# Epoch 00030: val_loss did not improve from 0.00078
# Epoch 31/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.3104e-04 - val_loss: 7.6997e-04
#
# Epoch 00031: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.3272e-04 - val_loss: 7.8441e-04
#
# Epoch 00032: val_loss did not improve from 0.00077
# Epoch 33/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2474e-04 - val_loss: 8.0676e-04
#
# Epoch 00033: val_loss did not improve from 0.00077
# Epoch 34/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2005e-04 - val_loss: 8.8667e-04
#
# Epoch 00034: val_loss did not improve from 0.00077
# Epoch 35/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2333e-04 - val_loss: 8.0119e-04
#
# Epoch 00035: val_loss did not improve from 0.00077
# Epoch 36/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1527e-04 - val_loss: 7.7996e-04
#
# Epoch 00036: val_loss did not improve from 0.00077
# Epoch 37/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1560e-04 - val_loss: 8.3539e-04
#
# Epoch 00037: val_loss did not improve from 0.00077
# Epoch 38/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0920e-04 - val_loss: 8.4713e-04
#
# Epoch 00038: val_loss did not improve from 0.00077
# Epoch 39/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0405e-04 - val_loss: 8.1896e-04
#
# Epoch 00039: val_loss did not improve from 0.00077
# Epoch 40/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0222e-04 - val_loss: 7.8967e-04
#
# Epoch 00040: val_loss did not improve from 0.00077
# Epoch 41/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9508e-04 - val_loss: 7.5814e-04
#
# Epoch 00041: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 42/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9670e-04 - val_loss: 7.7652e-04
#
# Epoch 00042: val_loss did not improve from 0.00076
# Epoch 43/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9009e-04 - val_loss: 7.5328e-04
#
# Epoch 00043: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 44/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9247e-04 - val_loss: 7.7093e-04
#
# Epoch 00044: val_loss did not improve from 0.00075
# Epoch 45/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8626e-04 - val_loss: 7.9322e-04
#
# Epoch 00045: val_loss did not improve from 0.00075
# Epoch 46/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8131e-04 - val_loss: 7.6080e-04
#
# Epoch 00046: val_loss did not improve from 0.00075
# Epoch 47/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9116e-04 - val_loss: 7.7547e-04
#
# Epoch 00047: val_loss did not improve from 0.00075
# Epoch 48/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8039e-04 - val_loss: 7.9581e-04
#
# Epoch 00048: val_loss did not improve from 0.00075
# Epoch 49/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7986e-04 - val_loss: 7.7842e-04
#
# Epoch 00049: val_loss did not improve from 0.00075
# Epoch 50/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7216e-04 - val_loss: 7.5335e-04
#
# Epoch 00050: val_loss did not improve from 0.00075
# Epoch 51/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7620e-04 - val_loss: 7.9454e-04
#
# Epoch 00051: val_loss did not improve from 0.00075
# Epoch 52/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7635e-04 - val_loss: 8.2948e-04
#
# Epoch 00052: val_loss did not improve from 0.00075
# Epoch 53/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7728e-04 - val_loss: 8.0866e-04
#
# Epoch 00053: val_loss did not improve from 0.00075
# Epoch 54/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7299e-04 - val_loss: 7.7799e-04
#
# Epoch 00054: val_loss did not improve from 0.00075
# Epoch 55/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6879e-04 - val_loss: 7.9746e-04
#
# Epoch 00055: val_loss did not improve from 0.00075
# Epoch 56/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6263e-04 - val_loss: 7.6065e-04
#
# Epoch 00056: val_loss did not improve from 0.00075
# Epoch 57/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6088e-04 - val_loss: 8.4251e-04
#
# Epoch 00057: val_loss did not improve from 0.00075
# Epoch 58/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6286e-04 - val_loss: 7.9013e-04
#
# Epoch 00058: val_loss did not improve from 0.00075
# Epoch 59/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6110e-04 - val_loss: 7.5855e-04
#
# Epoch 00059: val_loss did not improve from 0.00075
# Epoch 60/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5421e-04 - val_loss: 7.7761e-04
#
# Epoch 00060: val_loss did not improve from 0.00075
# Epoch 61/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5702e-04 - val_loss: 7.3950e-04
#
# Epoch 00061: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 62/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5698e-04 - val_loss: 7.6490e-04
#
# Epoch 00062: val_loss did not improve from 0.00074
# Epoch 63/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5074e-04 - val_loss: 7.8050e-04
#
# Epoch 00063: val_loss did not improve from 0.00074
# Epoch 64/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5784e-04 - val_loss: 8.1951e-04
#
# Epoch 00064: val_loss did not improve from 0.00074
# Epoch 65/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5553e-04 - val_loss: 7.6206e-04
#
# Epoch 00065: val_loss did not improve from 0.00074
# Epoch 66/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5044e-04 - val_loss: 7.4809e-04
#
# Epoch 00066: val_loss did not improve from 0.00074
# Epoch 67/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4771e-04 - val_loss: 8.1830e-04
#
# Epoch 00067: val_loss did not improve from 0.00074
# Epoch 68/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4813e-04 - val_loss: 7.7487e-04
#
# Epoch 00068: val_loss did not improve from 0.00074
# Epoch 69/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4734e-04 - val_loss: 7.6635e-04
#
# Epoch 00069: val_loss did not improve from 0.00074
# Epoch 70/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4312e-04 - val_loss: 7.8731e-04
#
# Epoch 00070: val_loss did not improve from 0.00074
# Epoch 71/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4165e-04 - val_loss: 7.6163e-04
#
# Epoch 00071: val_loss did not improve from 0.00074
# Epoch 72/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4429e-04 - val_loss: 7.4529e-04
#
# Epoch 00072: val_loss did not improve from 0.00074
# Epoch 73/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3722e-04 - val_loss: 7.7323e-04
#
# Epoch 00073: val_loss did not improve from 0.00074
# Epoch 74/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3617e-04 - val_loss: 7.4782e-04
#
# Epoch 00074: val_loss did not improve from 0.00074
# Epoch 75/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3412e-04 - val_loss: 7.6905e-04
#
# Epoch 00075: val_loss did not improve from 0.00074
# Epoch 76/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3373e-04 - val_loss: 7.8644e-04
#
# Epoch 00076: val_loss did not improve from 0.00074
# Epoch 77/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3922e-04 - val_loss: 7.9613e-04
#
# Epoch 00077: val_loss did not improve from 0.00074
# Epoch 78/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3548e-04 - val_loss: 7.8839e-04
#
# Epoch 00078: val_loss did not improve from 0.00074
# Epoch 79/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3367e-04 - val_loss: 7.3800e-04
#
# Epoch 00079: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 80/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3246e-04 - val_loss: 7.8068e-04
#
# Epoch 00080: val_loss did not improve from 0.00074
# Epoch 81/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2469e-04 - val_loss: 7.5388e-04
#
# Epoch 00081: val_loss did not improve from 0.00074
# Epoch 82/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3216e-04 - val_loss: 7.8596e-04
#
# Epoch 00082: val_loss did not improve from 0.00074
# Epoch 83/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2848e-04 - val_loss: 8.1222e-04
#
# Epoch 00083: val_loss did not improve from 0.00074
# Epoch 84/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2328e-04 - val_loss: 7.6079e-04
#
# Epoch 00084: val_loss did not improve from 0.00074
# Epoch 85/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2266e-04 - val_loss: 7.9510e-04
#
# Epoch 00085: val_loss did not improve from 0.00074
# Epoch 86/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2247e-04 - val_loss: 7.5215e-04
#
# Epoch 00086: val_loss did not improve from 0.00074
# Epoch 87/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2451e-04 - val_loss: 7.8216e-04
#
# Epoch 00087: val_loss did not improve from 0.00074
# Epoch 88/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2536e-04 - val_loss: 7.4896e-04
#
# Epoch 00088: val_loss did not improve from 0.00074
# Epoch 89/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2429e-04 - val_loss: 7.6355e-04
#
# Epoch 00089: val_loss did not improve from 0.00074
# Epoch 90/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2035e-04 - val_loss: 7.4575e-04
#
# Epoch 00090: val_loss did not improve from 0.00074
# Epoch 91/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1958e-04 - val_loss: 7.4150e-04
#
# Epoch 00091: val_loss did not improve from 0.00074
# Epoch 92/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1485e-04 - val_loss: 7.8296e-04
#
# Epoch 00092: val_loss did not improve from 0.00074
# Epoch 93/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1644e-04 - val_loss: 7.8783e-04
# Epoch 00093: val_loss did not improve from 0.00074
# Epoch 94/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1696e-04 - val_loss: 7.6806e-04
#
# Epoch 00094: val_loss did not improve from 0.00074
# Epoch 95/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1823e-04 - val_loss: 7.6859e-04
#
# Epoch 00095: val_loss did not improve from 0.00074
# Epoch 96/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1682e-04 - val_loss: 7.9444e-04
#
# Epoch 00096: val_loss did not improve from 0.00074
# Epoch 97/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1410e-04 - val_loss: 8.2269e-04
#
# Epoch 00097: val_loss did not improve from 0.00074
# Epoch 98/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1324e-04 - val_loss: 7.8432e-04
#
# Epoch 00098: val_loss did not improve from 0.00074
# Epoch 99/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1270e-04 - val_loss: 7.8936e-04
#
# Epoch 00099: val_loss did not improve from 0.00074
# Epoch 100/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1173e-04 - val_loss: 7.4773e-04
#
# Epoch 00100: val_loss did not improve from 0.00074
# Epoch 101/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1241e-04 - val_loss: 7.7894e-04
#
# Epoch 00101: val_loss did not improve from 0.00074
# Epoch 102/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1297e-04 - val_loss: 7.4940e-04
#
# Epoch 00102: val_loss did not improve from 0.00074
# Epoch 103/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1277e-04 - val_loss: 7.8254e-04
#
# Epoch 00103: val_loss did not improve from 0.00074
# Epoch 104/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1071e-04 - val_loss: 7.6868e-04
#
# Epoch 00104: val_loss did not improve from 0.00074
# Epoch 105/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1037e-04 - val_loss: 7.8585e-04
#
# Epoch 00105: val_loss did not improve from 0.00074
# Epoch 106/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0708e-04 - val_loss: 8.4398e-04
#
# Epoch 00106: val_loss did not improve from 0.00074
# Epoch 107/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0736e-04 - val_loss: 7.7293e-04
#
# Epoch 00107: val_loss did not improve from 0.00074
# Epoch 108/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0640e-04 - val_loss: 7.6169e-04
#
# Epoch 00108: val_loss did not improve from 0.00074
# Epoch 109/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0620e-04 - val_loss: 7.5101e-04
#
# Epoch 00109: val_loss did not improve from 0.00074
# Epoch 110/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0563e-04 - val_loss: 7.6635e-04
#
# Epoch 00110: val_loss did not improve from 0.00074
# Epoch 111/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0242e-04 - val_loss: 8.0022e-04
#
# Epoch 00111: val_loss did not improve from 0.00074
# Epoch 112/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0190e-04 - val_loss: 8.1636e-04
#
# Epoch 00112: val_loss did not improve from 0.00074
# Epoch 113/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0077e-04 - val_loss: 7.6356e-04
#
# Epoch 00113: val_loss did not improve from 0.00074
# Epoch 114/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0403e-04 - val_loss: 7.7991e-04
#
# Epoch 00114: val_loss did not improve from 0.00074
# Epoch 115/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0345e-04 - val_loss: 8.2072e-04
#
# Epoch 00115: val_loss did not improve from 0.00074
# Epoch 116/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0253e-04 - val_loss: 7.8520e-04
#
# Epoch 00116: val_loss did not improve from 0.00074
# Epoch 117/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.8503e-05 - val_loss: 7.8720e-04
#
# Epoch 00117: val_loss did not improve from 0.00074
# Epoch 118/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0155e-04 - val_loss: 7.6556e-04
#
# Epoch 00118: val_loss did not improve from 0.00074
# Epoch 119/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0008e-04 - val_loss: 7.8401e-04
#
# Epoch 00119: val_loss did not improve from 0.00074
# Epoch 120/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0121e-04 - val_loss: 7.5350e-04
#
# Epoch 00120: val_loss did not improve from 0.00074
# Epoch 121/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.8238e-05 - val_loss: 7.6458e-04
#
# Epoch 00121: val_loss did not improve from 0.00074
# Epoch 122/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.6067e-05 - val_loss: 7.7433e-04
#
# Epoch 00122: val_loss did not improve from 0.00074
# Epoch 123/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0036e-04 - val_loss: 7.6351e-04
#
# Epoch 00123: val_loss did not improve from 0.00074
# Epoch 124/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.6629e-05 - val_loss: 7.9210e-04
#
# Epoch 00124: val_loss did not improve from 0.00074
# Epoch 125/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.7622e-05 - val_loss: 8.0068e-04
#
# Epoch 00125: val_loss did not improve from 0.00074
# Epoch 126/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.5861e-05 - val_loss: 7.5076e-04
#
# Epoch 00126: val_loss did not improve from 0.00074
# Epoch 127/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.4701e-05 - val_loss: 7.8524e-04
#
# Epoch 00127: val_loss did not improve from 0.00074
# Epoch 128/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.6759e-05 - val_loss: 7.8549e-04
#
# Epoch 00128: val_loss did not improve from 0.00074
# Epoch 129/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2213e-05 - val_loss: 7.5898e-04
#
# Epoch 00129: val_loss did not improve from 0.00074
# Epoch 130/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2747e-05 - val_loss: 7.5741e-04
#
# Epoch 00130: val_loss did not improve from 0.00074
# Epoch 131/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2136e-05 - val_loss: 7.6582e-04
#
# Epoch 00131: val_loss did not improve from 0.00074
# Epoch 132/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.1103e-05 - val_loss: 7.7144e-04
#
# Epoch 00132: val_loss did not improve from 0.00074
# Epoch 133/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0436e-05 - val_loss: 8.1931e-04
#
# Epoch 00133: val_loss did not improve from 0.00074
# Epoch 134/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.3369e-05 - val_loss: 7.7475e-04
#
# Epoch 00134: val_loss did not improve from 0.00074
# Epoch 135/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.9370e-05 - val_loss: 7.7400e-04
#
# Epoch 00135: val_loss did not improve from 0.00074
# Epoch 136/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.8084e-05 - val_loss: 7.7457e-04
#
# Epoch 00136: val_loss did not improve from 0.00074
# Epoch 137/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.6971e-05 - val_loss: 7.5330e-04
#
# Epoch 00137: val_loss did not improve from 0.00074
# Epoch 138/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.7641e-05 - val_loss: 7.8534e-04
#
# Epoch 00138: val_loss did not improve from 0.00074
# Epoch 139/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.7218e-05 - val_loss: 7.6851e-04
#
# Epoch 00139: val_loss did not improve from 0.00074
# Epoch 140/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.1162e-05 - val_loss: 7.9602e-04
#
# Epoch 00140: val_loss did not improve from 0.00074
# Epoch 141/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.9155e-05 - val_loss: 7.6769e-04
#
# Epoch 00141: val_loss did not improve from 0.00074
# Epoch 142/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.4212e-05 - val_loss: 7.9216e-04
#
# Epoch 00142: val_loss did not improve from 0.00074
# Epoch 143/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.7299e-05 - val_loss: 8.0643e-04
#
# Epoch 00143: val_loss did not improve from 0.00074
# Epoch 144/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.6594e-05 - val_loss: 7.7973e-04
#
# Epoch 00144: val_loss did not improve from 0.00074
# Epoch 145/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.7540e-05 - val_loss: 7.8547e-04
#
# Epoch 00145: val_loss did not improve from 0.00074
# Epoch 146/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.5727e-05 - val_loss: 7.4779e-04
#
# Epoch 00146: val_loss did not improve from 0.00074
# Epoch 147/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.6560e-05 - val_loss: 7.6152e-04
#
# Epoch 00147: val_loss did not improve from 0.00074
# Epoch 148/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.6531e-05 - val_loss: 8.0339e-04
#
# Epoch 00148: val_loss did not improve from 0.00074
# Epoch 149/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.8042e-05 - val_loss: 7.6995e-04
#
# Epoch 00149: val_loss did not improve from 0.00074
# Epoch 150/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.3766e-05 - val_loss: 7.7393e-04
#
# Epoch 00150: val_loss did not improve from 0.00074

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 17s 5ms/step - loss: 0.0066 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00204, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 0.0016 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00204 to 0.00194, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00194 to 0.00188, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00188
# Epoch 5/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 9.8936e-04 - val_loss: 0.0017
#
# Epoch 00005: val_loss improved from 0.00188 to 0.00169, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 7.7663e-04 - val_loss: 0.0014
#
# Epoch 00006: val_loss improved from 0.00169 to 0.00141, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 16s 5ms/step - loss: 6.1267e-04 - val_loss: 0.0011
#
# Epoch 00007: val_loss improved from 0.00141 to 0.00106, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 5.2541e-04 - val_loss: 9.5256e-04
#
# Epoch 00008: val_loss improved from 0.00106 to 0.00095, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 4.6770e-04 - val_loss: 8.7749e-04
#
# Epoch 00009: val_loss improved from 0.00095 to 0.00088, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 4.3650e-04 - val_loss: 8.8826e-04
#
# Epoch 00010: val_loss did not improve from 0.00088
# Epoch 11/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 4.0233e-04 - val_loss: 8.2451e-04
#
# Epoch 00011: val_loss improved from 0.00088 to 0.00082, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 3.7355e-04 - val_loss: 7.9158e-04
#
# Epoch 00012: val_loss improved from 0.00082 to 0.00079, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 3.4600e-04 - val_loss: 7.7415e-04
#
# Epoch 00013: val_loss improved from 0.00079 to 0.00077, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 3.3286e-04 - val_loss: 7.4507e-04
#
# Epoch 00014: val_loss improved from 0.00077 to 0.00075, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 3.2128e-04 - val_loss: 7.5109e-04
#
# Epoch 00015: val_loss did not improve from 0.00075
# Epoch 16/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.9893e-04 - val_loss: 7.1936e-04
#
# Epoch 00016: val_loss improved from 0.00075 to 0.00072, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 2.9545e-04 - val_loss: 6.8563e-04
#
# Epoch 00017: val_loss improved from 0.00072 to 0.00069, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 2.8082e-04 - val_loss: 6.9094e-04
#
# Epoch 00018: val_loss did not improve from 0.00069
# Epoch 19/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.7151e-04 - val_loss: 6.8769e-04
#
# Epoch 00019: val_loss did not improve from 0.00069
# Epoch 20/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.6895e-04 - val_loss: 6.8123e-04
#
# Epoch 00020: val_loss improved from 0.00069 to 0.00068, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.6160e-04 - val_loss: 6.5306e-04
#
# Epoch 00021: val_loss improved from 0.00068 to 0.00065, saving model to best_weights_augment.h5
# Epoch 22/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.5088e-04 - val_loss: 6.9632e-04
#
# Epoch 00022: val_loss did not improve from 0.00065
# Epoch 23/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.5468e-04 - val_loss: 6.5934e-04
#
# Epoch 00023: val_loss did not improve from 0.00065
# Epoch 24/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.4129e-04 - val_loss: 6.5127e-04
#
# Epoch 00024: val_loss improved from 0.00065 to 0.00065, saving model to best_weights_augment.h5
# Epoch 25/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.4121e-04 - val_loss: 6.3396e-04
#
# Epoch 00025: val_loss improved from 0.00065 to 0.00063, saving model to best_weights_augment.h5
# Epoch 26/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.2715e-04 - val_loss: 6.5760e-04
#
# Epoch 00026: val_loss did not improve from 0.00063
# Epoch 27/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.2352e-04 - val_loss: 6.7267e-04
#
# Epoch 00027: val_loss did not improve from 0.00063
# Epoch 28/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.2285e-04 - val_loss: 6.6223e-04
#
# Epoch 00028: val_loss did not improve from 0.00063
# Epoch 29/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.1849e-04 - val_loss: 6.4199e-04
#
# Epoch 00029: val_loss did not improve from 0.00063
# Epoch 30/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.0888e-04 - val_loss: 6.1885e-04
#
# Epoch 00030: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 31/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.0627e-04 - val_loss: 6.0395e-04
#
# Epoch 00031: val_loss improved from 0.00062 to 0.00060, saving model to best_weights_augment.h5
# Epoch 32/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.0303e-04 - val_loss: 6.1424e-04
#
# Epoch 00032: val_loss did not improve from 0.00060
# Epoch 33/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.0270e-04 - val_loss: 6.3525e-04
#
# Epoch 00033: val_loss did not improve from 0.00060
# Epoch 34/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.9408e-04 - val_loss: 6.1598e-04
#
# Epoch 00034: val_loss did not improve from 0.00060
# Epoch 35/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.9107e-04 - val_loss: 6.1314e-04
#
# Epoch 00035: val_loss did not improve from 0.00060
# Epoch 36/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.8597e-04 - val_loss: 6.2124e-04
#
# Epoch 00036: val_loss did not improve from 0.00060
# Epoch 37/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.8737e-04 - val_loss: 6.0124e-04
#
# Epoch 00037: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 38/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.8618e-04 - val_loss: 5.9679e-04
#
# Epoch 00038: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 39/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.8290e-04 - val_loss: 6.2620e-04
#
# Epoch 00039: val_loss did not improve from 0.00060
# Epoch 40/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.7887e-04 - val_loss: 6.1198e-04
#
# Epoch 00040: val_loss did not improve from 0.00060
# Epoch 41/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.7476e-04 - val_loss: 6.0588e-04
#
# Epoch 00041: val_loss did not improve from 0.00060
# Epoch 42/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.7028e-04 - val_loss: 5.9642e-04
#
# Epoch 00042: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 43/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.7220e-04 - val_loss: 6.0804e-04
#
# Epoch 00043: val_loss did not improve from 0.00060
# Epoch 44/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.6830e-04 - val_loss: 6.1963e-04
#
# Epoch 00044: val_loss did not improve from 0.00060
# Epoch 45/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.6289e-04 - val_loss: 6.0298e-04
#
# Epoch 00045: val_loss did not improve from 0.00060
# Epoch 46/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.6125e-04 - val_loss: 5.9222e-04
#
# Epoch 00046: val_loss improved from 0.00060 to 0.00059, saving model to best_weights_augment.h5
# Epoch 47/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.5932e-04 - val_loss: 6.0927e-04
#
# Epoch 00047: val_loss did not improve from 0.00059
# Epoch 48/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.5807e-04 - val_loss: 5.8495e-04
#
# Epoch 00048: val_loss improved from 0.00059 to 0.00058, saving model to best_weights_augment.h5
# Epoch 49/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.5624e-04 - val_loss: 6.0432e-04
#
# Epoch 00049: val_loss did not improve from 0.00058
# Epoch 50/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.5639e-04 - val_loss: 5.8964e-04
#
# Epoch 00050: val_loss did not improve from 0.00058
# Epoch 51/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.5230e-04 - val_loss: 6.2134e-04
#
# Epoch 00051: val_loss did not improve from 0.00058
# Epoch 52/150
# 3424/3424 [==============================] - 16s 5ms/step - loss: 1.5022e-04 - val_loss: 6.2122e-04
#
# Epoch 00052: val_loss did not improve from 0.00058
# Epoch 53/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.5055e-04 - val_loss: 6.3209e-04
#
# Epoch 00053: val_loss did not improve from 0.00058
# Epoch 54/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.4880e-04 - val_loss: 6.1333e-04
#
# Epoch 00054: val_loss did not improve from 0.00058
# Epoch 55/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.4598e-04 - val_loss: 6.3560e-04
#
# Epoch 00055: val_loss did not improve from 0.00058
# Epoch 56/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.4280e-04 - val_loss: 6.0974e-04
#
# Epoch 00056: val_loss did not improve from 0.00058
# Epoch 57/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.4041e-04 - val_loss: 6.2109e-04
#
# Epoch 00057: val_loss did not improve from 0.00058
# Epoch 58/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3651e-04 - val_loss: 6.2059e-04
#
# Epoch 00058: val_loss did not improve from 0.00058
# Epoch 59/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3837e-04 - val_loss: 6.1793e-04
#
# Epoch 00059: val_loss did not improve from 0.00058
# Epoch 60/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3731e-04 - val_loss: 6.0848e-04
#
# Epoch 00060: val_loss did not improve from 0.00058
# Epoch 61/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3823e-04 - val_loss: 5.9716e-04
#
# Epoch 00061: val_loss did not improve from 0.00058
# Epoch 62/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3151e-04 - val_loss: 6.0346e-04
#
# Epoch 00062: val_loss did not improve from 0.00058
# Epoch 63/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3127e-04 - val_loss: 6.3686e-04
#
# Epoch 00063: val_loss did not improve from 0.00058
# Epoch 64/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3152e-04 - val_loss: 5.9755e-04
#
# Epoch 00064: val_loss did not improve from 0.00058
# Epoch 65/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.2786e-04 - val_loss: 6.0078e-04
#
# Epoch 00065: val_loss did not improve from 0.00058
# Epoch 66/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.2738e-04 - val_loss: 5.9744e-04
#
# Epoch 00066: val_loss did not improve from 0.00058
# Epoch 67/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.2567e-04 - val_loss: 6.0471e-04
#
# Epoch 00067: val_loss did not improve from 0.00058
# Epoch 68/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.2681e-04 - val_loss: 6.0791e-04
#
# Epoch 00068: val_loss did not improve from 0.00058
# Epoch 69/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.2308e-04 - val_loss: 6.0572e-04
#
# Epoch 00069: val_loss did not improve from 0.00058
# Epoch 70/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.2143e-04 - val_loss: 5.9325e-04
#
# Epoch 00070: val_loss did not improve from 0.00058
# Epoch 71/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.2181e-04 - val_loss: 6.1797e-04
#
# Epoch 00071: val_loss did not improve from 0.00058
# Epoch 72/150
# 3392/3424 [============================>.] - ETA: 0s - loss: 1.2357e-04

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
